# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
cities = pd.read_csv("../output_data/cities.csv")
CityWeather = pd.read_csv("../output_data/CityWeather.csv")
DataforScatterplots = pd.read_csv("../output_data/DataforScatterplots.csv")

CityWeather.head()
# Out:
#               City Country  Temperature  Humidity  Cloudiness  Windspeed  \
# 0            Luwuk      ID        77.49        80          52       5.61
# 1         Hamilton      US        82.00        69           1       3.36
# 2            Yushu      CN        64.00        72          99       8.05
# 3          Paamiut      GL        37.18        92         100       8.59
# 4  Charters Towers      AU        60.46        80          20       6.35
#
#          Date  Longitude  Latitude
# 0  1592581443     122.79     -0.95
# 1  1592580663     -84.53     39.18
# 2  1592581443     126.53     44.80
# 3  1592581016     -49.67     61.99
# 4  1592581075     146.27    -20.10

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
citylocation = CityWeather[["Latitude", "Longitude"]]
humidity = CityWeather["Humidity"]
gmaps.configure(api_key=g_key)
layout = {
    'width': '1000px',
    'height': '600px',
    'border': '1px solid black',
    'padding': '1px'}

fig = gmaps.figure(map_type="TERRAIN", zoom_level=1.5, center=(0,0), layout=layout)
Humidity_layer = gmaps.heatmap_layer(citylocation, weights=humidity, 
                                 dissipating=False, max_intensity=100,
                                 point_radius=1)

fig.add_layer(Humidity_layer)

fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='600px', padding='1px', width='1000px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
Filtered_data = CityWeather.loc[CityWeather['Humidity']<=50]
Filtered_data = Filtered_data.loc[Filtered_data["Temperature"] >= 65]
Filtered_data = Filtered_data.loc[Filtered_data['Temperature'] <= 85]
Filtered_data = Filtered_data.loc[Filtered_data['Windspeed'] <= 10]
print(Filtered_data.count())
Filtered_data.head()
# Out:
# City           51
# Country        50
# Temperature    51
# Humidity       51
# Cloudiness     51
# Windspeed      51
# Date           51
# Longitude      51
# Latitude       51
# dtype: int64
#                City Country  Temperature  Humidity  Cloudiness  Windspeed  \
# 14            Iporá      BR        81.91        41          67       6.31
# 43     Saint George      US        73.40        17           1       6.93
# 46         Cherskiy      RU        69.71        45          74       1.88
# 48  Arraial do Cabo      BR        82.40        45          71       6.93
# 55           Manono      CD        80.94        38          13       4.97
#
#           Date  Longitude  Latitude
# 14  1592581446     -51.12    -16.44
# 43  1592580674    -113.58     37.10
# 46  1592581451     161.30     68.75
# 48  1592580851     -42.03    -22.97
# 55  1592581453      27.42     -7.30

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_df= Filtered_data
hotel_df['Hotel Name'] = ""
hotel_df['Hotel Lat'] = ""
hotel_df['Hotel Lng'] = ""
hotel_df['Hotel Rating'] = ""
params = {
    "radius": 50000,
    "types": "hotel",
    "keyword": "hotel",
    "key": g_key
    }
for index, row in hotel_df.iterrows():
    lat = row["Latitude"]
    lng = row["Longitude"]
    city = row["City"]
    params["location"] = f'{lat},{lng}'
    
    apiurl = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    hotel_api = requests.get(apiurl, params=params)
#     print(hotel_api.url)
    hotel_api = hotel_api.json()
    
    try:
        hotel_df.loc[index, "Hotel Name"] = hotel_api["results"][0]["name"]
        hotel_df.loc[index, "Hotel Lat"] = hotel_api["results"][0]["geometry"]["location"]['lat']
        hotel_df.loc[index, "Hotel Lng"] = hotel_api["results"][0]["geometry"]["location"]['lng']
        hotel_df.loc[index, "Hotel Rating"] = hotel_api["results"][0]["rating"]
    except:
        print(f"Missing results for {city}, skipping entry")

hotel_df.head()
# Out:
# Missing results for Cherskiy, skipping entry
# Missing results for Bukama, skipping entry
# Missing results for Chokurdakh, skipping entry
# Missing results for Srednekolymsk, skipping entry
# Missing results for Belaya Gora, skipping entry
#                City Country  Temperature  Humidity  Cloudiness  Windspeed  \
# 14            Iporá      BR        81.91        41          67       6.31
# 43     Saint George      US        73.40        17           1       6.93
# 46         Cherskiy      RU        69.71        45          74       1.88
# 48  Arraial do Cabo      BR        82.40        45          71       6.93
# 55           Manono      CD        80.94        38          13       4.97
#
#           Date  Longitude  Latitude                               Hotel Name  \
# 14  1592581446     -51.12    -16.44                              Grand Hotel
# 43  1592580674    -113.58     37.10  Casablanca Resort, Casino, Golf and Spa
# 46  1592581451     161.30     68.75
# 48  1592580851     -42.03    -22.97                    Hotel Ilha Branca Inn
# 55  1592581453      27.42     -7.30                          Hotel hewa bora
#
#    Hotel Lat Hotel Lng Hotel Rating
# 14  -16.4349  -51.1115          4.3
# 43   36.8022  -114.101          4.1
# 46
# 48  -22.7444  -41.8772          4.2
# 55  -7.29285   27.3958            0

# %%
nan_value = float("NaN")
hotel_df.replace("", nan_value, inplace=True)
hotel_df.dropna(subset=['Hotel Name'], inplace=True)
# Out:
#                 City Country  Temperature  Humidity  Cloudiness  Windspeed  \
# 14             Iporá      BR        81.91        41          67       6.31
# 43      Saint George      US        73.40        17           1       6.93
# 48   Arraial do Cabo      BR        82.40        45          71       6.93
# 55            Manono      CD        80.94        38          13       4.97
# 75         Saskylakh      RU        69.24        47          39       6.49
# 84          Sagarejo      GE        78.80        41          75       8.05
# 100         Lüderitz     NaN        80.60        21           0       9.17
# 119   Port Elizabeth      ZA        75.20        29           0       3.36
# 123   Saint-François      FR        71.60        43          52       6.93
# 128         Hermanus      ZA        68.00        48           0       5.99
# 167          Mafinga      TZ        73.53        43          27       2.53
# 176         Guanambi      BR        82.74        46          66       9.57
# 201         Marsabit      KE        74.50        47          57       8.46
# 209    Szentgotthárd      HU        72.00        32          64       7.00
# 228         Živinice      BA        82.40        34          20       4.70
# 258         Almaznyy      RU        82.40        34          20       4.47
# 291  Yangi Marg`ilon      UZ        84.20        20          15       2.24
# 302            Afşin      TR        68.54        48          81       4.34
# 308      Hämeenlinna      FI        82.00        50          40       7.67
# 328             Åmot      NO        82.00        37          62       1.99
# 330         Menongue      AO        68.56        33          23       4.65
# 341         Malartic      CA        80.01        44           5       4.70
# 345       Farmington      US        72.00        20           1       6.93
# 372           Naples      IT        79.00        50          20       3.36
# 408          Kashgar      CN        82.40        12          75       6.71
# 417       Kiryat Gat      IL        80.01        33           0       1.01
# 431           Msanga      TZ        75.20        50          40       9.17
# 440          Ludvika      SE        80.01        39          62       8.01
# 444          Vangaži      LV        84.20        42          63       6.93
# 449         Karratha      AU        72.00        47           0       4.92
# 472           Deyang      CN        81.00         1         100       0.76
# 128                         Krystal Beach Hotel -34.151429   18.859175
# 167                           Ruaha Dream Villa  -7.628052   34.803990
# 176                               Hotel Caetité -14.064950  -42.485318
# 201                       Jirime Hotel & Resort   2.360824   38.006365
# 209      Das Sonnreich Thermenhotel Loipersdorf  46.984343   16.114810
# 228                             Royal Spa Hotel  44.514464   19.153590
# 258                                   Art Otel'  48.307645   40.282067
# 291                          Hotel Mehmon Saroy  40.384188   71.781349
# 302                              Eylül Bungalow  38.049342   36.476829
# 308                               Hotel Sveitsi  60.632615   24.832556
# 328                              Dalen Hotel AS  59.443872    8.011441
# 330                                  Ritz Lauca -14.655517   17.684072
# 341                    Hôtel Nouvelle Frontière  48.560874  -78.079654
# 345            Courtyard by Marriott Farmington  36.730232 -108.188963
# 372       Renaissance Naples Hotel Mediterraneo  40.841046   14.250598
# 408                  Radisson Blu Hotel Kashgar  39.447990   76.003120
# 417                   Waldorf Astoria Jerusalem  31.777403   35.222048
# 431                            New Dodoma Hotel  -6.184437   35.749249
# 440              Best Western Gustaf Wasa Hotel  60.482014   15.428786
# 444             Royal Casino Spa & Resort Hotel  56.959231   24.133538
# 449                        ibis Styles Karratha -20.732173  116.846737
# 472                     Hilton Chengdu Chenghua  30.684526  104.097890
# 478                        Likya Evleri Olympos  36.390340   30.467383
# 479                      Hotel Rafa Cassilândia -19.113682  -51.733122
# 480               Clarion Hotel Grand Östersund  63.179839   14.636200
# 487                           Hotel King Castle  32.233290   76.327140
# 492                         Shahdag Hotel & Spa  41.319558   48.135995
# 502                                 SANDO HOTEL  -3.526782   23.593667
# 503                          Hotel Borisoglebsk  51.365998   42.080249
# 525                             Hotel Brosundet  62.472454    6.152234
# 527                            Château d'Étoges  48.881903    3.851287
# 535                         Serena Hotel Quetta  30.204409   67.012245
# 542                                Abacus Motel -20.699471  139.486778
# 547                              Hôtel Matagami  49.756264  -77.633705
# 556                              Aweser resorts  35.216765   46.187531
# 557            Hotel Fazenda Thermas Bonsucesso -17.817524  -51.771575
# 570                    Hotel Portal do Corrente -13.391142  -44.205955
#
#      Hotel Rating
# 14            4.3
# 43            4.1
# 48            4.2
# 55            0.0
# 75            4.5
# 84            4.4
# 100           4.2
# 119           4.3
# 123           4.2
# 128           4.4
# 167           0.0
# 176           4.3
# 201           3.9
# 209           4.6
# 228           4.3
# 258           4.3
# 291           4.3
# 302           4.3
# 308           4.3
# 328           4.6
# 330           3.0
# 341           4.2
# 345           4.1
# 372           4.4
# 408           4.6
# 417           4.7
# 431           3.7
# 440           4.0
# 444           4.6
# 449           3.4
# 472           4.4
# 478           4.5
# 479           4.7
# 480           4.2
# 487           4.4
# 492           4.5
# 502           4.7
# 503           3.7
# 525           4.5
# 527           4.6
# 535           4.3
# 542           4.6
# 547           4.0
# 556           4.8
# 557           4.5
# 570           4.5

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Hotel Lat", "Hotel Lng"]]

# %%
# Add marker layer ontop of heat map
markers = gmaps.marker_layer(locations)
fig.add_layer(markers)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='600px', padding='1px', width='1000px'))
